# %%
# %%time
import os
from functools import reduce
# load, sort and cut two useless
filenames = list(filter(lambda x: x[0:3] == 'avg', sorted(os.listdir('data'))))

data = ""

with open(f'data/{filenames[0]}') as f:
    data += f.readline()

for filename in filenames:
    with open(f'data/{filename}') as f:
        raw = f.read()
        data += raw[raw.find('\n') + 1:]
        
#with open("data/data.csv", "w") as f:
#    f.write(data)
# Out:
# CPU times: user 233 ms, sys: 680 ms, total: 913 ms
# Wall time: 1.31 s

# %%
import pandas as pd

# %%
import os
from functools import reduce

# %%
# %%time
dir_path = 'data/'
files = sorted([f for f in os.listdir(dir_path) if f[:3] == 'avg'])
merged_df = pd.concat([pd.read_csv(dir_path + f) for f in files])
d.to_csv(dir_path + 'merged.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <timed exec>:4, in <module>
#
# NameError: name 'd' is not defined

# %%
d = pd.read_csv(dir_path + files[0])
d.to_csv('huj.csv', index=False )
d = pd.read_csv('huj.csv')
d
# Out:
#                            czas  001fcx00211.pv  001fcx00221.pv  \
# 0     2020-10-01 00:00:00+02:00       56.729077       54.724422
# 1     2020-10-01 00:01:00+02:00       54.771942       54.734675
# 2     2020-10-01 00:02:00+02:00       54.695816       54.774163
# 3     2020-10-01 00:03:00+02:00       54.154394       54.985713
# 4     2020-10-01 00:04:00+02:00       54.693184       54.490742
# ...                         ...             ...             ...
# 1435  2020-10-01 23:55:00+02:00       54.852689       54.900221
# 1436  2020-10-01 23:56:00+02:00       54.243661       54.862048
# 1437  2020-10-01 23:57:00+02:00       54.293406       54.699712
# 1438  2020-10-01 23:58:00+02:00       55.574638       55.016979
# 1439  2020-10-01 23:59:00+02:00       55.396874       55.207819
#
#       001fcx00231.pv  001fcx00241.pv  001fir01307.daca.pv  \
# 0          11.966905       22.493207           108.702362
# 1          12.026410       22.593412           108.846612
# 2          11.953671       22.428933           108.827640
# 3          12.052065       22.335388           108.623473
# 4          12.027310       22.412620           108.746784
# ...              ...             ...                  ...
# 1435       10.029970       19.987846           108.289526
# 1436       10.013064       20.120451           108.435637
# 1437        9.913703       20.161320           108.406886
# 1438       10.021135       20.124558           108.489068
# 1439        9.998830       19.978884           108.379532
#
#       001fir01308.daca.pv  001fir01309.daca.pv  001fir01310.daca.pv  \
# 0              112.280388           110.013796           108.761583
# 1              112.334600           109.906645           108.879083
# 2              112.362508           109.970932           108.844765
# 3              112.386061           109.836948           108.717994
# 4              112.396792           109.966910           108.978605
# ...                   ...                  ...                  ...
# 1435           112.387656           109.967809           109.044998
# 1436           112.287749           110.000058           109.026684
# 1437           112.270480           109.945288           108.800030
# 1438           112.266324           109.956871           108.987352
# 1439           112.336223           109.866009           108.936230
#
# 4          12.027310       22.412620           108.746784
# ...              ...             ...                  ...
# 1435       10.056829       30.486496           101.111263
# 1436        9.935828       29.830075           101.034501
# 1437       10.014864       29.350514           101.251020
# 1438       10.048125       29.496899           101.073264
# 1439        9.909967       29.537882           101.171321
#
#       001fir01308.daca.pv  001fir01309.daca.pv  001fir01310.daca.pv  \
# 0              112.280388           110.013796           108.761583
# 1              112.334600           109.906645           108.879083
# 2              112.362508           109.970932           108.844765
# 3              112.386061           109.836948           108.717994
# 4              112.396792           109.966910           108.978605
# ...                   ...                  ...                  ...
# 1435            98.338021           102.332506           101.967828
# 1436            98.362465           102.332450           101.981035
# 1437            98.353221           102.312023           102.017297
# 1438            98.354741           102.336123           101.967655
# 1439            98.336003           102.331086           101.969703
#
#       001fir01311.daca.pv  ...  001uxm0rf01.daca.pv  001uxm0rf02.daca.pv  \
# 0              110.604901  ...            92.090454            92.024078
# 1              110.644046  ...            92.090534            92.024206
# 2              110.621665  ...            92.090613            92.024334
# 3              110.464245  ...            92.090692            92.024462
# 4              110.603660  ...            92.090771            92.024590
# ...                   ...  ...                  ...                  ...
# 1435           100.651891  ...            98.016144            98.121880
# 1436           100.575884  ...            98.016144            98.121319
# 1437           100.621084  ...            98.016144            98.120757
# 1438           100.596174  ...            98.016144            98.120196
# 1439           100.690806  ...            98.016144            98.119783
#
#       001uxm0rf03.daca.pv  037tix00254.daca.pv  037tix00264.daca.pv  \
# 0               92.405281            24.665309            24.526161
# 1               92.405239            24.663982            24.526161
# 2               92.405196            24.662656            24.526161
# 3               92.405153            24.661329            24.526161
# 4               92.405110            24.660003            24.525475
# ...                   ...                  ...                  ...
# 1435            98.225985            24.460338            24.320295
# 1436            98.226027            24.464324            24.322539
# 1437            98.226070            24.468310            24.324782
# 1438            98.226113            24.472296            24.327025
# 1439            98.226155            24.476282            24.329269
#
#       prazonka_fe  prazonka_s  prob_corg  prob_fe  prob_s
# 0            4.48        8.98        8.6     4.55    9.87
# 1            4.48        8.98        8.6     4.55    9.87
# 2            4.48        8.98        8.6     4.55    9.87
# 3            4.48        8.98        8.6     4.55    9.87
# 4            4.48        8.98        8.6     4.55    9.87
# ...           ...         ...        ...      ...     ...
# 1435         6.18        8.89        7.8     6.65   12.47
# 1436         6.18        8.89        7.8     6.65   12.47
# 1437         6.18        8.89        7.8     6.65   12.47
# 1438         6.18        8.89        7.8     6.65   12.47
# 1439         6.18        8.89        7.8     6.65   12.47
#
# [702780 rows x 58 columns]

# %%
df = pd.read_csv('data/merged.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 df = pd.read_csv('data/merged.csv')
#
# File ~/anaconda3/envs/cuvalleyhack/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/cuvalleyhack/lib/python3.9/site-packages/pandas/io/parsers/readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File ~/anaconda3/envs/cuvalleyhack/lib/python3.9/site-packages/pandas/io/parsers/readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File ~/anaconda3/envs/cuvalleyhack/lib/python3.9/site-packages/pandas/io/parsers/readers.py:933, in TextFileReader.__init__(self, f, engine, **kwds)
#     930     self.options["has_index_names"] = kwds["has_index_names"]
#     932 self.handles: IOHandles | None = None
# --> 933 self._engine = self._make_engine(f, self.engine)
#
# File ~/anaconda3/envs/cuvalleyhack/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1217, in TextFileReader._make_engine(self, f, engine)
#    1213     mode = "rb"
#    1214 # error: No overload variant of "get_handle" matches argument types
#    1215 # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1216 # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1217 self.handles = get_handle(  # type: ignore[call-overload]
#    1218     f,
#    1219     mode,
#    1220     encoding=self.options.get("encoding", None),
#    1221     compression=self.options.get("compression", None),
#    1222     memory_map=self.options.get("memory_map", False),
#    1223     is_text=is_text,
#    1224     errors=self.options.get("encoding_errors", "strict"),
#    1225     storage_options=self.options.get("storage_options", None),
#    1226 )
#    1227 assert self.handles is not None
#    1228 f = self.handles.handle
#
# File ~/anaconda3/envs/cuvalleyhack/lib/python3.9/site-packages/pandas/io/common.py:789, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784 elif isinstance(handle, str):
#     785     # Check whether the filename is to be opened in binary mode.
#     786     # Binary mode does not support 'encoding' and 'newline'.
#     787     if ioargs.encoding and "b" not in ioargs.mode:
#     788         # Encoding
# --> 789         handle = open(
#     790             handle,
#     791             ioargs.mode,
#     792             encoding=ioargs.encoding,
#     793             errors=errors,
#     794             newline="",
#     795         )
#     796     else:
#     797         # Binary mode
#     798         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/merged.csv'

# %%
df['czas'] = pd.to_datetime(df['czas'])
