# %%
import pandas as pd
import numpy as np
import seaborn as sns

from data_processing.data_processing import *

# %% [markdown]
# # EDA on clear dataset

# %%
df = pd.read_csv('data/clear.csv')

# %%
sns.heatmap(data=df.corr(), annot=True)
# Out:
# <AxesSubplot:>
